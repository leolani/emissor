# %% [markdown]
# ## Download necessary stuff

# %%
# Download the annotations and stuff

# !git clone https://github.com/leolani/cltl-face-all

# !wget https://raw.githubusercontent.com/leolani/cltl-face-all/master/examples/smaller-datatsets-jsons/datasets.json


# !gdown --id 1-2LeHC_5Cm2gWWT6vBrVhp8jorbjkN1_
# !unzip visual-features.zip
# !rm visual-features.zip

# !gdown --id 16ck7plW9v9eSHGCs5wuB2AhhufPRt3Wi
# !unzip smaller-dataset.zip
# !rm smaller-dataset.zip

# %% [markdown]
# ## Read pre-computed visual features and annotations

# %%
import json
import numpy as np
import os
import json
import av
import cv2
import random
from glob import glob
import pickle
from datetime import datetime, timedelta

VISUAL_FEATURES_PATH = 'visual-features/'
VIDEOS_PATH = "smaller-dataset/"


with open('datasets.json', 'r') as stream:
    datasets = json.load(stream)

datasets = datasets['large']

visual_features = glob('visual-features/*.npy')
visual_features = {os.path.basename(vf).split('.npy')[0] : np.load(vf, allow_pickle=True).item() for vf in visual_features}

with open('friends-time/friends-time.pkl', 'rb') as stream:
    friends_time = pickle.load(stream)

# %% [markdown]
# ## Run on the images

# %%
import os
import av
import numpy as np
import cv2
from tqdm.notebook import tqdm
import time
import csv
from glob import glob
import numpy as np
import shutil

THRESHOLDS = {'face': 0.8, 'angle': 1.15}

predefined_faces = {}
for path in glob(os.path.join('./cltl-face-all/your-faces/*/*.npy')):
    name = path.split('/')[-2]
    predefined_faces[name] = np.load(path)

def calc_angle_distance(emb1, emb2):
    """Calculate the angle (radian) distance between the embeddings."""
    return np.arccos(np.clip((emb1 @ emb2.T), -1, 1))

def get_dias(list_of_diautts):
    return sorted(list(set([diautt.split('_')[0] for diautt in list_of_diautts])))

# %%
for DATASET in tqdm(['train', 'dev', 'test']):
    dataset = datasets[DATASET]
    diautts_ = list(dataset.keys())
    
    dias = get_dias(diautts_)
    diautts_ = {dia: [diautt for diautt in diautts_ if dia in diautt] for dia in dias}

    for dia, diautts in tqdm(diautts_.items()):
        shutil.rmtree(os.path.join('data', dia), ignore_errors=True)
        os.makedirs(os.path.join('data', dia, 'image'), exist_ok=True)
        os.makedirs(os.path.join('data', dia, 'text'), exist_ok=True)
        os.makedirs(os.path.join('data', dia, 'audio'), exist_ok=True)

        # annots = {diautt: datasets['train'][diautt] for diautt in diautts}
        # vids_path = {diautt: os.path.join(VIDEOS_PATH, diautt) +  '.mp4' for diautt in diautts}
        # features_path = {diautt: os.path.join(VISUAL_FEATURES_PATH, diautt) +  '.npy' for diautt in diautts}
        # features = {diautt: np.load(path, allow_pickle=True).item() for diautt, path in features_path.items()}

        image_grmc = []
        chat = []
        for diautt in tqdm(diautts):
            annot = datasets[DATASET][diautt] 
            vis = visual_features[diautt]
            vidpath = os.path.join(VIDEOS_PATH, diautt) + '.mp4'

            season = annot['Season']
            episode = annot['Episode']
            emotion = annot['Emotion']
            sentiment = annot['Sentiment']
            starttime = annot['StartTime']
            endttime = annot['EndTime']
            utterance = annot['Utterance']
            speaker = annot['Speaker']

            hours, minutes, seconds = starttime.split(':')
            seconds, milliseconds = seconds.split(',')

            hours, minutes, seconds, milliseconds = int(hours), int(minutes), int(seconds), int(milliseconds)

            time_datetime = friends_time[season][episode] + timedelta(hours=hours, minutes=minutes, seconds=seconds)
            time_unix = time.mktime(time_datetime.timetuple())
            time_unix_ms = int(time_unix*1000 + milliseconds)

            chat.append([speaker, utterance, time_unix_ms])

            aud = diautt + '.wav'
            # !ffmpeg -i $vidpath -q:a 0 -map a data/$dia/audio/$aud

            container = av.open(vidpath)
            fps = float(container.streams.video[0].average_rate)
            for frame in container.decode(video=0):
                idx = frame.index
                numpy_RGB = np.array(frame.to_image())
                numpy_BGR = cv2.cvtColor(numpy_RGB, cv2.COLOR_RGB2BGR)
                impath = os.path.join('data', dia, 'image', diautt + f'_frame{str(idx).zfill(5)}.jpg')
                cv2.imwrite(impath, numpy_BGR)

                features = vis[idx]
                # Assume that there is only one unique face per frame.
                for feat in features:
                    to_append = {}

                    age = float(feat['age'])
                    gender = float(feat['gender'])
                    bbox = feat['bbox']

                    bbox, faceprob = [int(round(bb)) for bb in bbox[:4]], float(bbox[-1])

                    embedding = feat['embedding']
                    landmark = feat['landmark']

                    if bbox[-1] < THRESHOLDS['face']:
                        continue

                    if speaker not in list(predefined_faces.keys()):
                        continue

                    embedding.reshape(1, 512)

                    dists = {key: calc_angle_distance(embedding, val) for key, val \
                                in predefined_faces.items()}

                    if dists[speaker] < THRESHOLDS['angle']:
                        to_append['files'] = impath
                        to_append['bbox'] = bbox
                        to_append['faceprob'] = round(faceprob, 3)
                        to_append['speaker'] = speaker
                        to_append['age'] = round(age, 3)
                        to_append['gender'] = round(gender, 3)

                        image_grmc.append(to_append)

        with open(os.path.join('data', dia, 'text', f'{dia}.csv'), 'w') as stream:
            stream.write('speaker,utterance,time\n')

            for line in chat:
                speaker, utterance, time_unix_ms = line
                stream.write(speaker)
                stream.write(',')
                stream.write(f"\"{utterance}\"")
                stream.write(',')
                stream.write(str(time_unix_ms))
                stream.write('\n')    

        with open(os.path.join('data', dia, 'image.json'), 'w') as stream:
            json.dump(image_grmc, stream)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=64.0), HTML(value='')))
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=4.0), HTML(value='')))
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1000_utt0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:04.03, start: 0.000000, bitrate: 2211 kb/s
#     Chapter #0:0: start 0.000000, end 4.003000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1812 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 398 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1000/audio/dia1000_utt0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 4.003000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    2256kB time=00:00:04.01 bitrate=4608.2kbits/s speed= 357x
# video:0kB audio:2256kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004415%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1000_utt1.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:02.27, start: 0.000000, bitrate: 2602 kb/s
#     Chapter #0:0: start 0.000000, end 2.251000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2215 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 394 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1000/audio/dia1000_utt1.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 2.251000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1272kB time=00:00:02.26 bitrate=4608.4kbits/s speed= 307x
# video:0kB audio:1272kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007831%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1000_utt2.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:03.61, start: 0.000000, bitrate: 2111 kb/s
#     Chapter #0:0: start 0.000000, end 3.586000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1713 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 398 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1000/audio/dia1000_utt2.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 3.586000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    2028kB time=00:00:03.60 bitrate=4608.2kbits/s speed= 381x
# video:0kB audio:2028kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.004912%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1000_utt3.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:05.15, start: 0.000000, bitrate: 2615 kb/s
#     Chapter #0:0: start 0.000000, end 5.129000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2220 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 395 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1000/audio/dia1000_utt3.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 5.129000
#     Metadata:
#       title           : 00:01:58.910
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    2892kB time=00:00:05.14 bitrate=4608.2kbits/s speed= 289x
# video:0kB audio:2892kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003444%
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=16.0), HTML(value='')))
#  --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.19, start: 0.000000, bitrate: 3571 kb/s
#     Chapter #0:0: start 0.000000, end 3.168000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 3240 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 3.168000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1788kB time=00:00:03.17 bitrate=4608.3kbits/s speed= 328x
# video:0kB audio:1788kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005571%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:05.48, start: 0.000000, bitrate: 3392 kb/s
#     Chapter #0:0: start 0.000000, end 5.462000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 3053 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 5.462000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    3084kB time=00:00:05.48 bitrate=4608.1kbits/s speed= 237x
# video:0kB audio:3084kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003230%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:08.66, start: 0.000000, bitrate: 2326 kb/s
#     Chapter #0:0: start 0.000000, end 8.633000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1981 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt6.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 8.633000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    4860kB time=00:00:08.64 bitrate=4608.1kbits/s speed= 456x
# video:0kB audio:4860kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002050%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.07, start: 0.000000, bitrate: 1494 kb/s
#     Chapter #0:0: start 0.000000, end 3.043000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1150 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt7.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 3.043000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1716kB time=00:00:03.05 bitrate=4608.3kbits/s speed= 321x
# video:0kB audio:1716kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005805%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:02.48, start: 0.000000, bitrate: 1997 kb/s
#     Chapter #0:0: start 0.000000, end 2.460000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1658 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 340 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt8.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 2.460000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1392kB time=00:00:02.47 bitrate=4608.3kbits/s speed= 280x
# video:0kB audio:1392kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.007156%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1007_utt9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:03.19, start: 0.000000, bitrate: 1357 kb/s
#     Chapter #0:0: start 0.000000, end 3.169000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1011 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia1007/audio/dia1007_utt9.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 3.169000
#     Metadata:
#       title           : 00:11:54.714
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1788kB time=00:00:03.17 bitrate=4608.3kbits/s speed= 337x
# video:0kB audio:1788kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.005571%
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=18.0), HTML(value='')))
# flite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1029_utt7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:01.56, start: 0.000000, bitrate: 2736 kb/s
#     Chapter #0:0: start 0.000000, end 1.542000
#     Metadata:
#       title           : 00:01:55.782
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2359 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 392 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia102/audio/dia1029_utt7.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 1.542000
#     Metadata:
#       title           : 00:01:55.782
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     876kB time=00:00:01.55 bitrate=4608.5kbits/s speed= 264x
# video:0kB audio:876kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011371%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1029_utt8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:11.82, start: 0.000000, bitrate: 2163 kb/s
#     Chapter #0:0: start 0.000000, end 4.296000
#     Metadata:
#       title           : 00:01:55.782
#     Chapter #0:1: start 4.296000, end 11.802000
#     Metadata:
#       title           : 00:09:28.651
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1763 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 395 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia102/audio/dia1029_utt8.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 4.296000
#     Metadata:
#       title           : 00:01:55.782
#     Chapter #0:1: start 4.296000, end 11.802000
#     Metadata:
#       title           : 00:09:28.651
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    6648kB time=00:00:11.81 bitrate=4608.1kbits/s speed= 380x
# video:0kB audio:6648kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001498%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia1029_utt9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:07.74, start: 0.000000, bitrate: 2481 kb/s
#     Chapter #0:0: start 0.000000, end 7.715000
#     Metadata:
#       title           : 00:01:55.782
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2084 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 394 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia102/audio/dia1029_utt9.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 7.715000
#     Metadata:
#       title           : 00:01:55.782
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    4344kB time=00:00:07.72 bitrate=4608.1kbits/s speed= 489x
# video:0kB audio:4344kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002293%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia102_utt0.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:06.99, start: 0.000000, bitrate: 2232 kb/s
#     Chapter #0:0: start 0.000000, end 6.964000
#     Metadata:
#       title           : 00:02:09.254
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1888 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 341 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia102/audio/dia102_utt0.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 6.964000
#     Metadata:
#       title           : 00:02:09.254
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    3924kB time=00:00:06.97 bitrate=4608.1kbits/s speed= 414x
# video:0kB audio:3924kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002538%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
# ...
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia549_utt4.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:01.56, start: 0.000000, bitrate: 1900 kb/s
#     Chapter #0:0: start 0.000000, end 1.542000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1507 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 397 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia549/audio/dia549_utt4.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 1.542000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=     876kB time=00:00:01.55 bitrate=4608.5kbits/s speed= 187x
# video:0kB audio:876kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.011371%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia549_utt5.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:05.86, start: 0.000000, bitrate: 2362 kb/s
#     Chapter #0:0: start 0.000000, end 5.838000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1966 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 394 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia549/audio/dia549_utt5.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 5.838000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    3288kB time=00:00:05.84 bitrate=4608.1kbits/s speed= 312x
# video:0kB audio:3288kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.003029%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia549_utt6.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:02.69, start: 0.000000, bitrate: 2528 kb/s
#     Chapter #0:0: start 0.000000, end 2.668000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2139 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 394 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# Stream mapping:
#   Stream #0:1 -> #0:0 (aac (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to 'data/dia549/audio/dia549_utt6.wav':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     ISFT            : Lavf58.29.100
#     Chapter #0:0: start 0.000000, end 2.668000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 5.1, s16, 4608 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#       encoder         : Lavc58.54.100 pcm_s16le
# size=    1512kB time=00:00:02.68 bitrate=4608.3kbits/s speed= 320x
# video:0kB audio:1512kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.006588%
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia549_utt7.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:02.32, start: 0.000000, bitrate: 2831 kb/s
#     Chapter #0:0: start 0.000000, end 2.293000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 2447 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 393 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# data/dia549/audio/dia549_utt7.wav: No such file or directory
# ffmpeg version 4.2.4-1ubuntu0.1 Copyright (c) 2000-2020 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.3.0-10ubuntu2)
#   configuration: --prefix=/usr --extra-version=1ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Guessed Channel Layout for Input Stream #0.1 : 5.1
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'smaller-dataset/dia549_utt8.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.12.100
#   Duration: 00:00:06.99, start: 0.000000, bitrate: 2150 kb/s
#     Chapter #0:0: start 0.000000, end 6.964000
#     Metadata:
#       title           : 00:02:29.232
#     Stream #0:0(eng): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1280x720 [SAR 1:1 DAR 16:9], 1752 kb/s, 23.98 fps, 23.98 tbr, 27021 tbn, 47.95 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#     Stream #0:1(eng): Audio: aac (LC) (mp4a / 0x6134706D), 48000 Hz, 5.1, fltp, 395 kb/s (default)
#     Metadata:
#       handler_name    : SoundHandler
#     Stream #0:2(eng): Data: bin_data (text / 0x74786574), 0 kb/s
#     Metadata:
#       handler_name    : SubtitleHandler
# data/dia549/audio/dia549_utt8.wav: No such file or directory
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-ed32e44e82af> in <module>
#      52                 idx = frame.index
#      53                 numpy_RGB = np.array(frame.to_image())
# ---> 54                 numpy_BGR = cv2.cvtColor(numpy_RGB, cv2.COLOR_RGB2BGR)
#      55                 impath = os.path.join('data', dia, 'image', diautt + f'_frame{str(idx).zfill(5)}.jpg')
#      56                 cv2.imwrite(impath, numpy_BGR)
#
# TypeError: Expected Ptr<cv::UMat> for argument 'src'
